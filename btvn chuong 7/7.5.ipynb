# %%
import tkinter as tk
from PIL import Image, ImageTk

root = tk.Tk()
root.title("Xem ảnh")

img = Image.open("Otto.png")   # đổi tên ảnh nếu cần
img = img.resize((400, 250))
photo = ImageTk.PhotoImage(img)

label = tk.Label(root, image=photo)
label.pack()

root.mainloop()
