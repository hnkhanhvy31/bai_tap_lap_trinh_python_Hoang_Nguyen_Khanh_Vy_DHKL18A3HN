# %%
import numpy as np
#a
stock1=np.genfromtxt('stocks1.csv',encoding='UTF-8',names=True,delimiter=',')
print(stock1)

print(stock1[:5])
print(stock1[-5:])

print(stock1.dtype)
# Out:
# [(nan, nan, 100., 105.,  98., 104., 10000.)
#  (nan, nan, 102., 106., 101., 103., 12000.)
#  (nan, nan,  50.,  55.,  48.,  54.,  8000.)
#  (nan, nan,  52.,  54.,  50.,  51.,  7500.)
#  (nan, nan,  80.,  85.,  78.,  84.,  9000.)]
# [(nan, nan, 100., 105.,  98., 104., 10000.)
#  (nan, nan, 102., 106., 101., 103., 12000.)
#  (nan, nan,  50.,  55.,  48.,  54.,  8000.)
#  (nan, nan,  52.,  54.,  50.,  51.,  7500.)
#  (nan, nan,  80.,  85.,  78.,  84.,  9000.)]
# [(nan, nan, 100., 105.,  98., 104., 10000.)
#  (nan, nan, 102., 106., 101., 103., 12000.)
#  (nan, nan,  50.,  55.,  48.,  54.,  8000.)
#  (nan, nan,  52.,  54.,  50.,  51.,  7500.)
#  (nan, nan,  80.,  85.,  78.,  84.,  9000.)]
# [('\ufeffdate', '<f8'), ('symbol', '<f8'), ('open', '<f8'), ('high', '<f8'), ('low', '<f8'), ('close', '<f8'), ('volume', '<f8')]

# %%
stock2=np.genfromtxt('stocks2.csv',encoding='UTF-8',names=True,delimiter=',')
companies=np.genfromtxt('companies.csv',encoding='UTF-8',names=True,delimiter=',')
