# %%
#1
import numpy as np
drinks=np.genfromtxt('drinks.csv',encoding='UTF-8',names=True,delimiter=',',dtype=None)
print('kiểu dữ liệu: ',type(drinks))
print('kích thước: ',drinks.shape)
print('tên các cột: ',drinks.dtype.names)
print('in 5 dòng đầu: ',drinks[:5])
print('in 5 dòng cuối: ',drinks[-5:])
# Out:
# kiểu dữ liệu:  <class 'numpy.ndarray'>
# kích thước:  (2,)
# tên các cột:  ('\ufeff', 'Châu_Á', 'Châu_Âu', 'Châu_Phi', 'Châu_Mỹ', 'Châu_Đại_Dương')
# in 5 dòng đầu:  [('Bia', 120, 200, 60, 180, 90) ('Rượu',  80, 150, 40, 130, 70)]
# in 5 dòng cuối:  [('Bia', 120, 200, 60, 180, 90) ('Rượu',  80, 150, 40, 130, 70)]

# %%
#2
print(np.mean(drinks['Châu_Á']))
print(np.mean(drinks['Châu_Âu']))
print(np.mean(drinks['Châu_Phi']))
print(np.mean(drinks['Châu_Mỹ']))
print(np.mean(drinks['Châu_Đại_Dương']))
# Out:
# 100.0
# 175.0
# 50.0
# 155.0
# 80.0

# %%
#3
print(drinks['Rượu'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 #3
# ----> 2 print(drinks(['Rượu']))
#
# TypeError: 'numpy.ndarray' object is not callable
